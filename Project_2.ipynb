# %% [markdown]
# # Project 2

# %% [markdown]
# Let's visualize the realtionship or lack thereof of two datasets.
#
# We are going to see if there is a relationship between drough worlwide and global

# %%
import pandas as pd
import plotly.express as px

# %%
wine_aus = pd.read_csv("wineind.csv")

wine_aus.head()
# Out:
#    rownames         time  value
# 0         1  1980.000000  15136
# 1         2  1980.083333  16733
# 2         3  1980.166667  20016
# 3         4  1980.250000  17708
# 4         5  1980.333333  18019

# %%
fig = px.line(wine_aus, x="time", y="value")

fig
